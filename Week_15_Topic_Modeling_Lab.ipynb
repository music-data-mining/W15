# %% [markdown]
# # Week 15 Topic Modeling

# %% [markdown]
# ### Task 1. Change some parameters (optional)
# Run the codes below to find topics from song lyrics by using NMF and LDA. If you want to change a few settings, change the following parameters:
# - `n_components` in NMF() and LatentDirichletAllocation(): total number of topics
# - `max_df` in CountVectorizer() and TfidfVectorizer (): ignore terms that appear in more than max_df% songs
# - `min_df` in CountVectorizer() and TfidfVectorizer (): ignore terms that appear in only less than min_df songs
# - `ngram` in CountVectorizer() and TfidfVectorizer (): unigram and/or bigram and/or trigram?
#
# ### Task 2. Analyze the results (optional)
# - Try to name topics based on their most dominant words. Topics are stored in NMF_topics.csv and LDA_topics.csv. (rows: topics, columns: words)
# - Can you find some coherent topics? Can you also see some junk topics that you cannot come up with meaning names?
# - Pick a few sample song lyrics and take a look at their topic distributions. Do they make sense?
# - Do the relationship between genres and their dominant topics make sense?

# %%
import os
import csv
import time
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation

# %%
# git clone "Music Dataset: Lyrics and Metadata from 1950 to 2019"
# the original corpus is adopted from https://data.mendeley.com/datasets/3t9vbwxgr5/2
if os.path.exists('W15'): 
    # !rm -fr 'W15/'
# !git clone https://github.com/music-data-mining/W15.git
# %cd W15
# Out:
# Cloning into 'W15'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 7 (delta 0), reused 7 (delta 0), pack-reused 0
# Unpacking objects: 100% (7/7), done.
# /content/W15/W15

# %% [markdown]
# ## Load Data
#
# We will be using lyrics from Music Dataset v2 ([*Music Dataset: Lyrics and Metadata from 1950 to 2019*](https://data.mendeley.com/datasets/3t9vbwxgr5/2)).

# %%
# read a relevant subset of the dataset
lyrics = pd.read_csv('tcc_ceds_music.csv', 
                     usecols=['artist_name', 'track_name', 'release_date', 'genre', 'lyrics', 'topic'])

# %%
# show 10 random rows
lyrics.sample(10)
# Out:
#                artist_name                         track_name  release_date  \
# 22250      the expendables                    one night stand          2002
# 158    t. m. soundararajan                        enna vendum          1958
# 19624           the meters                  down by the river          2001
# 3761             green day                            dry ice          1991
# 23469        elvis presley  it is no secret (what god can do)          1957
# 911              the byrds            all i really want to do          1965
# 3887         saint etienne                             spring          1992
# 24285                 toto                       georgy porgy          1978
# 9589               america              fallin' off the world          1984
# 6147         walk the moon                          tightrope          2012
#
#          genre                                             lyrics       topic
# 22250   reggae  night stand ringtone mobile phone gonna gonna ...    violence
# 158        pop  girl friend swag sauce drip swagu girl friends...     obscene
# 19624     jazz  reason hide madness sorrow impossible today oo...    violence
# 3761       pop  late night dream fly hand hand wake cold sweat...     sadness
# 23469     rock  chime time ring news slip fell long add streng...     sadness
# 911        pop  lookin compete beat cheat mistreat simplify cl...     obscene
# 3887       pop  eye need forget yesterday time love lose feel ...  world/life
# 24285     rock  situation need contemplation systematic addict...    romantic
# 9589   country  time feel heart beat want walkin street matter...  world/life
# 6147       pop  easy heart easy heart walk little tightrope wa...     sadness

# %%
print("Number of songs with lyrics: ", len(lyrics))
# Out:
# Number of songs with lyrics:  28372

# %% [markdown]
# Ok, we got a dataset of 28372 samples. It's pretty large. Can we quickly summarize the lyrics into topics? The anwser is Yes. Next we will use NMF and LDA to group the lyrics into topics.
#
# Notice, each sample is annotated with the topic in the dataset (there are eight categories: 'feelings', 'music', 'night/time', 'obscene', 'romantic', 'sadness', 'violence', and 'world/life'). We can, of course, build a classfier in a supervised manner. But a more realistic situation for topic modeling is 1) the dataset is very large to reveiw mannually and 2) we don't know the labels beforehand. So we want to first have a good overview of the possible topics in an unsupervised way.

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Before using the model, we need to transform the lyrics into a n*m matrix for our model to decompose. `n` is # of documents, `m` is # of unique word-level representation. A word-level representation can be a word ('unigram') or two consecutive words ('bigram'), w or w/t tf-idf transformation.
#
# We will be using feature engineering for texts learned before.
# - For both NMF and LDA, we will test term-freqency (tf) unigram matrix (using tf-idf is not recommended for its creator Blei: https://www.jmlr.org/papers/volume3/blei03a/blei03a.pdf?ref=https://githubhelp.com).
# - For NMF, we will test tf bigram and tf-idf unigram as well.

# %%
# by setting max_df==0.8 we remove common words (which is too common to indicate anything)
# by setting min_df==2 we remove very rare words only appear only in two docs; they can be miss/non-standard spellings
# stop_words arg indicate whether we want to remove very common words ("function words", e.g., 'is', 'of', and 'which')
tfv = CountVectorizer(max_df=0.8, min_df=2, stop_words='english', ngram_range=(1,1))
start_time = time.time()
tf_unigram = tfv.fit_transform(lyrics['lyrics'])
print("It took %s seconds to generate a TF unigram matrix for LDA" % (time.time() - start_time))
# the first dimention notes the row of the samples
# the second for the number of unique unigrams
print("tf.shape: ", tf_unigram.shape)
# Out:
# It took 1.7820885181427002 seconds to generate a TF matrix for LDA
# tf.shape:  (28372, 22720)

# %%
tfidfv_unigram = TfidfVectorizer(max_df=0.8, min_df=2, stop_words='english', ngram_range=(1,1))
start_time = time.time()
tfidf_unigram = tfidfv_unigram.fit_transform(lyrics['lyrics'])
print("It took %s seconds to generate a TFIDF unigram matrix for NMF" % (time.time() - start_time))
print("tfidf_unigram.shape: ", tfidf_unigram.shape)
# Out:
# It took 2.400155782699585 seconds to generate a TFIDF unigram matrix for NMF
# tfidf_unigram.shape:  (28372, 22720)

# %%
tfv_uni_bigram = CountVectorizer(max_df=0.5, min_df=5, stop_words='english', ngram_range=(1,2))
start_time = time.time()
tf_uni_bigram = tfv_uni_bigram.fit_transform(lyrics['lyrics'])
print("It took %s seconds to generate a TF bigram matrix for LDA" % (time.time() - start_time))
print("tf_uni_bigram.shape: ", tf_uni_bigram.shape)
# Out:
# It took 5.1385931968688965 seconds to generate a TF bigram matrix for LDA
# tf_uni_bigram.shape:  (28372, 50644)

# %% [markdown]
# ## 1. NMF

# %%
# fitting the NMF model with tfidf unigram features
# `n_components` is a rough estimation that how many latent topics we'd like to infer from data
# there is no harm to start from 30 or 10, it depends on you
nmf = NMF(n_components=30, solver='mu', init= 'nndsvda', beta_loss=1, random_state=42)
start_time = time.time()
nmf.fit(tfidf_unigram)
print("It took %s seconds to find NMF topics" % (time.time() - start_time))
# Out:
# It took 138.40290427207947 seconds to find NMF topics

# %%
start_time = time.time()
topics_nmf =[]
for index, topic in enumerate(nmf.components_): # H = nmf.components_
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    words = []
    for i in topic.argsort()[:-15-1:-1]: # the top 15 words
      words.append(tfidfv_unigram.get_feature_names_out()[i]) 
    print(words)
    topics_nmf.append(words) # the top 15 words per each topic
# with open("NMF_topics.csv", "w", newline="") as f:
#     writer = csv.writer(f)
#     writer.writerow(np.arange(1,16))
#     for l in topics_nmf:
#       writer.writerow(l)
print("It took %s seconds to generate NMF_topics.csv" % (time.time() - start_time))
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['like', 'check', 'straight', 'cause', 'number', 'damn', 'deal', 'beat', 'style', 'rhyme', 'kid', 'kick', 'drop', 'game', 'play']
# THE TOP 15 WORDS FOR TOPIC #1
# ['heart', 'break', 'tear', 'apart', 'start', 'promise', 'know', 'darling', 'inside', 'hearts', 'deep', 'eye', 'smile', 'pain', 'lose']
# THE TOP 15 WORDS FOR TOPIC #2
# ['time', 'mind', 'wait', 'years', 'forever', 'line', 'waste', 'pass', 'spend', 'lose', 'grow', 'wonder', 'search', 'know', 'maybe']
# THE TOP 15 WORDS FOR TOPIC #3
# ['away', 'walk', 'fade', 'run', 'yesterday', 'slip', 'throw', 'watch', 'blow', 'wind', 'river', 'stay', 'turn', 'place', 'drift']
# THE TOP 15 WORDS FOR TOPIC #4
# ['life', 'earth', 'power', 'shall', 'live', 'fate', 'spirit', 'strength', 'bless', 'holy', 'soul', 'rise', 'peace', 'beauty', 'praise']
# THE TOP 15 WORDS FOR TOPIC #5
# ['sweet', 'kiss', 'dear', 'heaven', 'moon', 'lover', 'bring', 'thrill', 'send', 'shin', 'warm', 'letter', 'lady', 'lips', 'till']
# THE TOP 15 WORDS FOR TOPIC #6
# ['ring', 'snow', 'band', 'bell', 'drum', 'blow', 'green', 'white', 'texas', 'silver', 'guitar', 'whistle', 'bass', 'hear', 'cowboy']
# THE TOP 15 WORDS FOR TOPIC #7
# ['hold', 'hand', 'close', 'touch', 'eye', 'arm', 'breathe', 'light', 'tight', 'reach', 'strong', 'open', 'afraid', 'moment', 'breath']
# THE TOP 15 WORDS FOR TOPIC #8
# ['baby', 'fall', 'fool', 'rain', 'piece', 'window', 'babe', 'fell', 'worry', 'come', 'little', 'crazy', 'like', 'crash', 'hurry']
# THE TOP 15 WORDS FOR TOPIC #9
# ['feel', 'good', 'make', 'morning', 'real', 'like', 'felt', 'fine', 'thing', 'know', 'wake', 'pain', 'swing', 'feelin', 'inside']
# THE TOP 15 WORDS FOR TOPIC #10
# ['ready', 'party', 'alright', 'drink', 'roll', 'sight', 'city', 'glass', 'tonight', 'street', 'midnight', 'floor', 'loose', 'light', 'bottle']
# THE TOP 15 WORDS FOR TOPIC #11
# ['long', 'tire', 'chain', 'anybody', 'distance', 'needle', 'silly', 'feat', 'pin', 'afternoon', 'hardest', 'hurtin', 'able', 'like', 'know']
# THE TOP 15 WORDS FOR TOPIC #12
# ['believe', 'save', 'reason', 'hate', 'answer', 'lie', 'truth', 'trust', 'point', 'future', 'mistake', 'blind', 'forgive', 'question', 'million']
# THE TOP 15 WORDS FOR TOPIC #13
# ['sing', 'hear', 'song', 'play', 'music', 'word', 'listen', 'sound', 'write', 'voice', 'songs', 'radio', 'loud', 'simple', 'tune']
# THE TOP 15 WORDS FOR TOPIC #14
# ['world', 'people', 'beautiful', 'wide', 'matter', 'everybody', 'welcome', 'rule', 'spin', 'message', 'string', 'nation', 'join', 'round', 'hand']
# THE TOP 15 WORDS FOR TOPIC #15
# ['home', 'cold', 'follow', 'stone', 'fight', 'grind', 'water', 'come', 'bone', 'land', 'ghost', 'build', 'mother', 'lord', 'house']
# THE TOP 15 WORDS FOR TOPIC #16
# ['live', 'blue', 'die', 'anymore', 'kill', 'lonesome', 'sick', 'edge', 'heal', 'grey', 'refuse', 'lose', 'release', 'shoe', 'bear']
# THE TOP 15 WORDS FOR TOPIC #17
# ['life', 'change', 'better', 'hard', 'easy', 'things', 'road', 'know', 'blame', 'ways', 'rest', 'trouble', 'shame', 'best', 'work']
# THE TOP 15 WORDS FOR TOPIC #18
# ['true', 'tonight', 'tomorrow', 'belong', 'care', 'minute', 'come', 'wonderful', 'nice', 'know', 'home', 'ohoh', 'certain', 'sugar', 'telephone']
# THE TOP 15 WORDS FOR TOPIC #19
# ['nothin', 'bout', 'goin', 'comin', 'lookin', 'livin', 'tryin', 'talkin', 'gettin', 'doin', 'lovin', 'shoot', 'somethin', 'runnin', 'thinkin']
# THE TOP 15 WORDS FOR TOPIC #20
# ['right', 'wrong', 'woman', 'thank', 'treat', 'mama', 'daddy', 'cheat', 'know', 'root', 'guilty', 'ought', 'exactly', 'hardly', 'say']
# THE TOP 15 WORDS FOR TOPIC #21
# ['love', 'remember', 'forget', 'today', 'goodbye', 'learn', 'money', 'stop', 'kind', 'friends', 'end', 'think', 'laugh', 'know', 'regret']
# THE TOP 15 WORDS FOR TOPIC #22
# ['night', 'late', 'sleep', 'gotta', 'steal', 'dance', 'weep', 'gimme', 'ball', 'shake', 'come', 'light', 'jump', 'wild', 'rainy']
# THE TOP 15 WORDS FOR TOPIC #23
# ['want', 'need', 'lonely', 'girl', 'lyric', 'commercial', 'nights', 'room', 'little', 'slowly', 'know', 'place', 'tell', 'loneliness', 'cause']
# THE TOP 15 WORDS FOR TOPIC #24
# ['dream', 'days', 'wish', 'memories', 'memory', 'hop', 'picture', 'year', 'someday', 'things', 'strange', 'christmas', 'nights', 'young', 'remind']
# THE TOP 15 WORDS FOR TOPIC #25
# ['yeah', 'miss', 'summer', 'whoa', 'winter', 'woah', 'lovely', 'bang', 'spring', 'autumn', 'beach', 'september', 'like', 'butterfly', 'cold']
# THE TOP 15 WORDS FOR TOPIC #26
# ['dead', 'black', 'blood', 'devil', 'alive', 'hell', 'death', 'scream', 'kill', 'bleed', 'hole', 'evil', 'burn', 'white', 'skin']
# THE TOP 15 WORDS FOR TOPIC #27
# ['gonna', 'leave', 'wanna', 'stay', 'hurt', 'somebody', 'cause', 'door', 'know', 'tell', 'sorry', 'darlin', 'want', 'beg', 'think']
# THE TOP 15 WORDS FOR TOPIC #28
# ['stand', 'head', 'hide', 'outside', 'come', 'look', 'shoulder', 'inside', 'cover', 'shout', 'wall', 'push', 'race', 'brain', 'dare']
# THE TOP 15 WORDS FOR TOPIC #29
# ['fuck', 'shit', 'bitch', 'nigga', 'niggas', 'like', 'money', 'tryna', 'fuckin', 'club', 'know', 'wanna', 'pussy', 'talk', 'hoe']
# It took 12.259369134902954 seconds to generate NMF_topics.csv

# %% [markdown]
# Does the clusters make sense? Algthough the `n_components` arg is arbitarily chosen, one out cluter in my output is very reasonable:
#
# ***
# THE TOP 15 WORDS FOR TOPIC #25
# ['yeah', 'miss', 'summer', 'whoa', 'winter', 'woah', 'lovely', 'bang', 'spring', 'autumn', 'beach', 'september', 'like', 'butterfly', 'cold']
# ***
#
# It seems the latent topic is 'season'.

# %%
topic_dist_NMF = nmf.transform(tfidf_unigram)

# %%
lyrics['Topic_NMF'] = topic_dist_NMF.argmax(axis=1) # assign the most dominant topic to each song
lyrics.sample(10) #show random rows
# Out:
#               artist_name               track_name  release_date    genre  \
# 16591         royal blood      you can be so cruel          2014    blues
# 15064               sweet              wig-wam bam          1993    blues
# 6004        avril lavigne       wish you were here          2011      pop
# 27729             freeman                 rescaper          2010  hip hop
# 5986        travis barker                 let's go          2011      pop
# 14271  the birthday party            6" gold blade          1982    blues
# 14921         louis prima          twist all night          1991    blues
# 5708              rihanna                disturbia          2008      pop
# 26606  david crowder band             how he loves          2009     rock
# 17067      gary clark jr.  don't wait til tomorrow          2019    blues
#
#                                                   lyrics       topic  \
# 16591  outside window outside door lonely show kill g...    violence
# 15064  suck bigger muthafucka right glass malone suck...     obscene
# 6004   tough strong like girl give shit wall walk rem...     obscene
# 27729  climb catacombs multi millions rest remain dea...     obscene
# 5986   barker yeah lelelet yelawolf lelelet twista ho...     obscene
# 14271  stick sixinch gold blade head girl lie teeth h...    violence
# 14921  come baby twist night come twist night come tw...  night/time
# 5708   bedum bedum wrong bedum bedum feel like bedum ...     obscene
# 26606  jealous love like hurricane tree bend beneath ...    romantic
# 17067  tire fight tire wrong hate cry wish right wron...  night/time
#
#        Topic_NMF
# 16591          1
# 15064         22
# 6004           0
# 27729         22
# 5986          22
# 14271          8
# 14921         10
# 5708          10
# 26606         24
# 17067         20

# %%
lyrics['Topic_NMF'] = lyrics['Topic_NMF'].apply(str)
lyrics.groupby(["genre"])[["Topic_NMF"]].describe() # show stats of the topics per each genre
# Out:
#         Topic_NMF
#             count unique top freq
# genre
# blues        4604     30  15  240
# country      5445     30   1  523
# hip hop       904     29  22  514
# jazz         3845     30  22  316
# pop          7042     30  22  539
# reggae       2498     30   4  269
# rock         4034     30  15  354

# %%
s = lyrics['Topic_NMF'].groupby(lyrics['genre']).value_counts()
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
  print(s)
# Out:
# genre    Topic_NMF
# blues    15           240
#          27           227
#          1            225
#          2            223
#          18           200
#          16           185
#          24           179
#          8            176
#          10           175
#          5            175
#          6            162
#          28           159
#          17           158
#          20           158
#          4            157
#          7            148
#          9            148
#          0            140
#          13           138
#          19           138
#          3            131
#          11           130
#          12           121
#          21           121
#          22           114
#          26           103
#          14           100
#          29            95
#          25            92
#          23            86
# country  1            523
#          2            341
#          18           299
#          6            266
#          10           264
#          5            248
#          17           245
#          13           236
#          7            230
#          29           186
#          24           179
#          12           178
#          19           173
#          28           162
#          21           161
#          25           159
#          15           148
#          8            148
#          0            145
#          11           128
#          16           127
#          3            125
#          20           122
#          26           113
#          4            109
#          27           101
#          23            96
#          9             92
#          14            74
#          22            67
# hip hop  22           514
#          15            31
#          0             25
#          4             24
#          20            22
#          6             22
#          18            20
#          28            20
#          25            19
#          27            19
#          3             16
#          11            15
#          21            14
#          10            13
#          12            12
#          14            12
#          8             12
#          26            11
#          13            10
#          23            10
#          1              9
#          16             9
#          29             9
#          17             8
#          19             7
#          24             7
#          9              6
#          2              5
#          7              3
# jazz     22           316
#          4            262
#          5            239
#          2            189
#          1            180
#          13           166
#          27           164
#          6            146
#          15           140
#          7            133
#          14           132
#          19           130
#          9            124
#          25           120
#          12           110
#          29           110
#          21           109
#          3            102
#          28            97
#          8             96
#          10            95
#          17            93
#          11            89
#          16            88
#          26            81
#          24            75
#          20            74
#          18            71
#          0             62
#          23            52
# pop      22           539
#          1            433
#          2            336
#          27           316
#          7            316
#          5            276
#          15           275
#          10           262
#          8            246
#          13           241
#          3            241
#          0            237
#          26           233
#          29           222
#          23           214
#          12           211
#          25           202
#          4            199
#          17           194
#          28           193
#          19           188
#          14           187
#          9            184
#          11           178
#          20           169
#          6            156
#          21           155
#          16           153
#          24           153
#          18           133
# reggae   4            269
#          22           258
#          18           251
#          14           156
#          15           112
#          2            101
#          10            79
#          27            75
#          20            71
#          3             71
#          16            70
#          25            68
#          0             66
#          13            65
#          24            65
#          28            64
#          12            63
#          1             56
#          11            54
#          17            52
#          26            52
#          6             51
#          21            48
#          19            46
#          29            46
#          9             45
#          23            44
#          8             42
#          7             40
#          5             18
# rock     15           354
#          27           336
#          2            227
#          4            221
#          1            191
#          7            188
#          3            175
#          10           142
#          12           138
#          0            132
#          14           130
#          20           129
#          23           121
#          16           117
#          18           110
#          29           108
#          17           106
#          11           101
#          6            101
#          8             90
#          21            88
#          9             88
#          24            87
#          26            86
#          28            86
#          25            83
#          13            75
#          19            75
#          5             75
#          22            74
# Name: Topic_NMF, dtype: int64

# %%
s.groupby('genre').head(3) # show the top 3 topics per genre
# Out:
# genre    Topic_NMF
# blues    15           240
#          27           227
#          1            225
# country  1            523
#          2            341
#          18           299
# hip hop  22           514
#          15            31
#          0             25
# jazz     22           316
#          4            262
#          5            239
# pop      22           539
#          1            433
#          2            336
# reggae   4            269
#          22           258
#          18           251
# rock     15           354
#          27           336
#          2            227
# Name: Topic_NMF, dtype: int64

# %% [markdown]
# ## 2. NMF with both TF unigram and bigram

# %%
nmf_uni_bigram = NMF(n_components=30, solver='mu', init= 'nndsvda', beta_loss=1, random_state=42)
start_time = time.time()
nmf_uni_bigram.fit(tf_uni_bigram)
print("It took %s seconds to find NMF topics" % (time.time() - start_time))
# Out:
# It took 169.89509439468384 seconds to find NMF topics

# %%
start_time = time.time()
topics_nmf2 =[]
for index,topic in enumerate(nmf_uni_bigram.components_): # H = nmf.components_
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    words = []
    for i in topic.argsort()[:-15-1:-1]: # the top 15 words
      words.append(tfv_uni_bigram.get_feature_names_out()[i]) 
    print(words)
    topics_nmf2.append(words) # the top 15 words per each topic

with open("NMF2_topics.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(np.arange(1,16))
    for l in topics_nmf2:
      writer.writerow(l)
      
print("It took %s seconds to generate NMF2_topics.csv" % (time.time() - start_time))
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['look', 'like', 'face', 'think', 'head', 'eye', 'place', 'open', 'say', 'make', 'try', 'lyric', 'cause', 'tell', 'commercial']
# THE TOP 15 WORDS FOR TOPIC #1
# ['time', 'time time', 'waste', 'line', 'come', 'think', 'time come', 'waste time', 'spend', 'turn', 'know time', 'second', 'fine', 'time know', 'lose']
# THE TOP 15 WORDS FOR TOPIC #2
# ['away', 'walk', 'stay', 'away away', 'fade', 'walk away', 'slip', 'turn', 'look', 'throw', 'hide', 'fade away', 'run', 'steal', 'today']
# THE TOP 15 WORDS FOR TOPIC #3
# ['like', 'fuck', 'shit', 'bitch', 'nigga', 'niggas', 'cause', 'come', 'real', 'gotta', 'check', 'tell', 'beat', 'wanna', 'tryna']
# THE TOP 15 WORDS FOR TOPIC #4
# ['feel', 'like', 'real', 'feel like', 'touch', 'feel feel', 'pain', 'inside', 'feel good', 'know feel', 'cause', 'ohoh', 'closer', 'good feel', 'body']
# THE TOP 15 WORDS FOR TOPIC #5
# ['yeah', 'yeah yeah', 'bout', 'whoa', 'talkin', 'woah', 'dirty', 'talk', 'talkin bout', 'like', 'drop', 'cause', 'yeah know', 'doin', 'whoa whoa']
# THE TOP 15 WORDS FOR TOPIC #6
# ['night', 'come', 'sleep', 'light', 'roll', 'come come', 'dance', 'night night', 'night long', 'morning', 'late', 'little', 'till', 'like', 'waitin']
# THE TOP 15 WORDS FOR TOPIC #7
# ['life', 'come', 'alive', 'life life', 'road', 'grow', 'bless', 'lead', 'simple', 'things', 'search', 'babylon', 'rest', 'thank', 'like']
# THE TOP 15 WORDS FOR TOPIC #8
# ['know', 'know know', 'think', 'tell', 'cause', 'mean', 'cause know', 'need', 'say', 'true', 'fever', 'thing', 'like', 'hard', 'know come']
# THE TOP 15 WORDS FOR TOPIC #9
# ['heart', 'wish', 'break heart', 'start', 'apart', 'tear', 'forever', 'deep', 'inside', 'like', 'eye', 'darling', 'beat', 'hurt', 'tell']
# THE TOP 15 WORDS FOR TOPIC #10
# ['hold', 'hand', 'kiss', 'arm', 'close', 'hold hold', 'touch', 'tight', 'lips', 'eye', 'lover', 'hold tight', 'close eye', 'hold hand', 'lovely']
# THE TOP 15 WORDS FOR TOPIC #11
# ['right', 'wrong', 'right right', 'teach', 'fight', 'right wrong', 'cause', 'say', 'feel right', 'right time', 'know right', 'time right', 'check', 'mama', 'belong']
# THE TOP 15 WORDS FOR TOPIC #12
# ['good', 'morning', 'feelin', 'lookin', 'like', 'good good', 'good time', 'everyday', 'lovin', 'luck', 'thinkin', 'livin', 'thing', 'cause', 'nothin']
# THE TOP 15 WORDS FOR TOPIC #13
# ['baby', 'girl', 'love', 'lonely', 'miss', 'hurt', 'baby baby', 'babe', 'need', 'lady', 'like', 'cause', 'strong', 'tell', 'come']
# THE TOP 15 WORDS FOR TOPIC #14
# ['long', 'wait', 'long long', 'long time', 'years', 'belong', 'wait wait', 'days', 'dear', 'come', 'tell', 'wrong', 'time long', 'stay', 'like']
# THE TOP 15 WORDS FOR TOPIC #15
# ['fall', 'fool', 'tear', 'rain', 'wall', 'fall fall', 'blame', 'like', 'cause', 'help', 'eye', 'stand', 'fall apart', 'pain', 'window']
# THE TOP 15 WORDS FOR TOPIC #16
# ['live', 'today', 'learn', 'tomorrow', 'people', 'live live', 'live life', 'like', 'die', 'life live', 'forever', 'yesterday', 'things', 'mean', 'live like']
# THE TOP 15 WORDS FOR TOPIC #17
# ['want', 'wanna', 'need', 'fuck', 'cause', 'sick', 'tell', 'shoot', 'want want', 'smoke', 'think', 'want know', 'wanna wanna', 'mouth', 'know want']
# THE TOP 15 WORDS FOR TOPIC #18
# ['gonna', 'tonight', 'party', 'alright', 'cause', 'goin', 'tonight tonight', 'like', 'runnin', 'gotta', 'gonna gonna', 'walkin', 'know gonna', 'evil', 'count']
# THE TOP 15 WORDS FOR TOPIC #19
# ['dream', 'blue', 'remember', 'sweet', 'true', 'bring', 'forget', 'promise', 'summer', 'come', 'thank', 'days', 'dear', 'memories', 'like']
# THE TOP 15 WORDS FOR TOPIC #20
# ['world', 'save', 'fear', 'reason', 'hate', 'eye', 'breathe', 'future', 'human', 'earth', 'lie', 'truth', 'wide', 'soul', 'come']
# THE TOP 15 WORDS FOR TOPIC #21
# ['leave', 'home', 'goodbye', 'come', 'blow', 'wind', 'come home', 'leave leave', 'train', 'say', 'lonesome', 'home home', 'soon', 'cause', 'place']
# THE TOP 15 WORDS FOR TOPIC #22
# ['sing', 'song', 'ring', 'songs', 'write', 'radio', 'sing song', 'swing', 'listen', 'hear', 'like', 'christmas', 'word', 'year', 'sing sing']
# THE TOP 15 WORDS FOR TOPIC #23
# ['believe', 'gotta', 'easy', 'trust', 'lord', 'river', 'believe believe', 'heaven', 'forgive', 'pray', 'need', 'come', 'tire', 'hard', 'make']
# THE TOP 15 WORDS FOR TOPIC #24
# ['money', 'work', 'comin', 'home', 'like', 'tell', 'cause', 'money money', 'sell', 'gettin', 'pay', 'come', 'paper', 'hard', 'gimme']
# THE TOP 15 WORDS FOR TOPIC #25
# ['hear', 'play', 'sound', 'music', 'ready', 'head', 'game', 'voice', 'come', 'word', 'band', 'listen', 'guitar', 'like', 'loud']
# THE TOP 15 WORDS FOR TOPIC #26
# ['better', 'little', 'cold', 'days', 'dead', 'late', 'shame', 'watch', 'knock', 'hide', 'nothin', 'head', 'say', 'better better', 'door']
# THE TOP 15 WORDS FOR TOPIC #27
# ['mind', 'change', 'woman', 'lose', 'follow', 'line', 'blind', 'inside', 'ways', 'things', 'mind mind', 'change change', 'think', 'woman woman', 'free']
# THE TOP 15 WORDS FOR TOPIC #28
# ['break', 'somebody', 'stand', 'fight', 'piece', 'hearts', 'bone', 'bleed', 'build', 'kick', 'break break', 'heart break', 'lie', 'tell', 'crash']
# THE TOP 15 WORDS FOR TOPIC #29
# ['black', 'kill', 'blood', 'devil', 'white', 'death', 'burn', 'hell', 'dead', 'stand', 'soul', 'hole', 'shoot', 'come', 'fight']
# It took 30.681180477142334 seconds to generate NMF2_topics.csv

# %%
topic_dist_NMF2 = nmf_uni_bigram.transform(tf_uni_bigram)

# %%
lyrics['Topic_NMF2'] = topic_dist_NMF2.argmax(axis=1)
lyrics.sample(10) # show 10 random rows
# Out:
#               artist_name                 track_name  release_date    genre  \
# 6011             go radio        rolling in the deep          2011      pop
# 7989         loretta lynn  put it off until tomorrow          1966  country
# 28240              n.w.a.      100 miles and runnin'          2018  hip hop
# 5445      new found glory               hold my hand          2006      pop
# 23066      sticky fingers               velvet skies          2014   reggae
# 11959  the be good tanyas         the littlest birds          2012  country
# 26745            bobaflex       bury me with my guns          2011     rock
# 11532  the be good tanyas         for the turnstiles          2006  country
# 17098         dean martin               just for fun          1950     jazz
# 7950         lorne greene                  i'm a gun          1966  country
#
#                                                   lyrics       topic  \
# 6011   start heart reach fever pitch bring dark final...     sadness
# 7989   tomorrow wowo hurt today go away leave tomorro...  world/life
# 28240  think gonna away spot immediate vicinity runni...     obscene
# 5445   hair swing eye motor head turn want long time ...    romantic
# 23066  come yeah alright baby music boys see light ru...    violence
# 11959  feel like hobo lonesome blue fair summer summe...       music
# 26745  conversations make sense stop suffer stop scre...    violence
# 11532  sailors seasick mamas hear sirens shore singin...  world/life
# 17098  softly sigh close maybe agree hand magic land ...     sadness
# 7950   bear blast furnace steel wonder shape hard col...    violence
#
#        Topic_NMF2
# 6011            9
# 7989            2
# 28240           3
# 5445           10
# 23066          27
# 11959          19
# 26745           0
# 11532          29
# 17098           2
# 7950           29

# %%
lyrics['Topic_NMF2']=lyrics['Topic_NMF2'].apply(str)
lyrics.groupby(["genre"])[["Topic_NMF2"]].describe() # show stats of the topics per each genre
# Out:
#         Topic_NMF2
#              count unique top freq
# genre
# blues         4604     30  29  319
# country       5445     30   9  409
# hip hop        904     30   3  615
# jazz          3845     30   3  439
# pop           7042     30   3  592
# reggae        2498     30   3  362
# rock          4034     30   0  389

# %%
s = lyrics['Topic_NMF2'].groupby(lyrics['genre']).value_counts()
s.groupby('genre').head(3) # show the top 3 topics per genre
# Out:
# genre    Topic_NMF2
# blues    29            319
#          0             253
#          13            193
# country  9             409
#          19            306
#          21            291
# hip hop  3             615
#          20             31
#          29             27
# jazz     3             439
#          20            347
#          19            247
# pop      3             592
#          0             504
#          9             366
# reggae   3             362
#          7             263
#          29            217
# rock     0             389
#          29            326
#          20            297
# Name: Topic_NMF2, dtype: int64

# %% [markdown]
# ------

# %% [markdown]
# ## 3. Latent Dirichlet Allocation (LDA)

# %%
lda = LatentDirichletAllocation(n_components=30, random_state=42)
start_time = time.time()
lda.fit(tf_unigram)
print("It took %s seconds to find LDA topics" % (time.time() - start_time))
# Out:
# It took 180.20423102378845 seconds to find LDA topics

# %%
start_time = time.time()
topics_lda =[]
for index,topic in enumerate(lda.components_): # H = nmf.components_
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    words = []
    for i in topic.argsort()[:-15-1:-1]: # the top 15 words
      words.append(tfv.get_feature_names_out()[i]) 
    print(words)
    topics_lda.append(words) # the top 15 words per each topic
# with open("LDA_topics.csv", "w", newline="") as f:
#     writer = csv.writer(f)
#     writer.writerow(np.arange(1,16))
#     for l in topics_lda:
#       writer.writerow(l)
print("It took %s seconds to generate LDA_topics.csv" % (time.time() - start_time))
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['black', 'open', 'hole', 'radio', 'teach', 'eye', 'point', 'like', 'bang', 'swing', 'pain', 'white', 'everybody', 'mama', 'texas']
# THE TOP 15 WORDS FOR TOPIC #1
# ['cold', 'hurt', 'write', 'game', 'minute', 'letter', 'read', 'oooh', 'cause', 'tell', 'burn', 'head', 'like', 'sittin', 'want']
# THE TOP 15 WORDS FOR TOPIC #2
# ['baby', 'wish', 'blood', 'come', 'girl', 'lady', 'bleed', 'luck', 'drink', 'check', 'power', 'head', 'watch', 'damn', 'run']
# THE TOP 15 WORDS FOR TOPIC #3
# ['feel', 'good', 'real', 'know', 'like', 'morning', 'woah', 'cause', 'moment', 'tire', 'ways', 'years', 'tell', 'thing', 'yeah']
# THE TOP 15 WORDS FOR TOPIC #4
# ['play', 'better', 'hear', 'music', 'devil', 'come', 'listen', 'like', 'band', 'sound', 'guitar', 'know', 'dance', 'say', 'thing']
# THE TOP 15 WORDS FOR TOPIC #5
# ['world', 'fight', 'ready', 'save', 'come', 'know', 'lose', 'share', 'battle', 'everybody', 'stand', 'say', 'steady', 'makin', 'word']
# THE TOP 15 WORDS FOR TOPIC #6
# ['time', 'days', 'remember', 'fool', 'know', 'mind', 'waste', 'think', 'spend', 'come', 'like', 'things', 'long', 'look', 'line']
# THE TOP 15 WORDS FOR TOPIC #7
# ['heart', 'fall', 'break', 'know', 'tear', 'stand', 'leave', 'like', 'lose', 'start', 'apart', 'cause', 'think', 'rain', 'pain']
# THE TOP 15 WORDS FOR TOPIC #8
# ['money', 'mind', 'nothin', 'talkin', 'night', 'tryin', 'dirty', 'yeah', 'late', 'walkin', 'know', 'goin', 'fever', 'lovin', 'gimme']
# THE TOP 15 WORDS FOR TOPIC #9
# ['right', 'little', 'somebody', 'yeah', 'wrong', 'know', 'hell', 'everyday', 'shout', 'heaven', 'help', 'like', 'make', 'say', 'work']
# THE TOP 15 WORDS FOR TOPIC #10
# ['night', 'gonna', 'tonight', 'sweet', 'bring', 'come', 'whoa', 'yeah', 'right', 'tomorrow', 'light', 'dance', 'know', 'roll', 'baby']
# THE TOP 15 WORDS FOR TOPIC #11
# ['like', 'shit', 'know', 'bitch', 'fuck', 'cause', 'nigga', 'niggas', 'yeah', 'tell', 'come', 'money', 'real', 'gotta', 'think']
# THE TOP 15 WORDS FOR TOPIC #12
# ['want', 'yeah', 'believe', 'party', 'come', 'girl', 'know', 'like', 'knock', 'cause', 'need', 'straight', 'alright', 'lookin', 'door']
# THE TOP 15 WORDS FOR TOPIC #13
# ['dream', 'need', 'promise', 'gotta', 'hand', 'mouth', 'face', 'shut', 'land', 'paradise', 'true', 'lyric', 'streets', 'commercial', 'plan']
# THE TOP 15 WORDS FOR TOPIC #14
# ['hand', 'blind', 'smile', 'smoke', 'closer', 'face', 'afraid', 'stick', 'crash', 'eye', 'laugh', 'tell', 'stop', 'look', 'place']
# THE TOP 15 WORDS FOR TOPIC #15
# ['woman', 'evil', 'lie', 'white', 'babylon', 'root', 'wicked', 'rise', 'bind', 'monkey', 'fear', 'travel', 'fall', 'come', 'know']
# THE TOP 15 WORDS FOR TOPIC #16
# ['change', 'kill', 'bout', 'things', 'girl', 'talk', 'feelin', 'christmas', 'like', 'come', 'thinkin', 'look', 'know', 'worry', 'cause']
# THE TOP 15 WORDS FOR TOPIC #17
# ['love', 'walk', 'shoot', 'ring', 'blow', 'wind', 'belong', 'hear', 'till', 'number', 'bell', 'know', 'rain', 'come', 'talk']
# THE TOP 15 WORDS FOR TOPIC #18
# ['live', 'people', 'life', 'inside', 'fear', 'come', 'free', 'step', 'truth', 'tear', 'like', 'things', 'mind', 'lose', 'world']
# THE TOP 15 WORDS FOR TOPIC #19
# ['sing', 'song', 'word', 'like', 'sweet', 'heart', 'songs', 'hear', 'know', 'come', 'summer', 'dream', 'lovely', 'moon', 'bring']
# THE TOP 15 WORDS FOR TOPIC #20
# ['head', 'wait', 'inside', 'turn', 'alive', 'touch', 'know', 'breathe', 'come', 'eye', 'need', 'light', 'look', 'leave', 'reach']
# THE TOP 15 WORDS FOR TOPIC #21
# ['away', 'know', 'stay', 'come', 'today', 'true', 'leave', 'look', 'forget', 'tell', 'think', 'goodbye', 'cause', 'fade', 'walk']
# THE TOP 15 WORDS FOR TOPIC #22
# ['dead', 'death', 'soul', 'come', 'hide', 'body', 'burn', 'sick', 'lord', 'blood', 'earth', 'scream', 'hell', 'lead', 'blame']
# THE TOP 15 WORDS FOR TOPIC #23
# ['wanna', 'wall', 'kick', 'cause', 'high', 'know', 'come', 'like', 'better', 'gyal', 'kid', 'sound', 'think', 'stand', 'tell']
# THE TOP 15 WORDS FOR TOPIC #24
# ['home', 'miss', 'thank', 'comin', 'shame', 'know', 'come', 'phone', 'lord', 'roam', 'paris', 'train', 'rebel', 'hear', 'daddy']
# THE TOP 15 WORDS FOR TOPIC #25
# ['long', 'blue', 'leave', 'darling', 'arm', 'sleep', 'dear', 'know', 'follow', 'close', 'kiss', 'time', 'dream', 'night', 'eye']
# THE TOP 15 WORDS FOR TOPIC #26
# ['life', 'lonely', 'know', 'lover', 'like', 'rest', 'dream', 'livin', 'think', 'river', 'steal', 'friend', 'best', 'come', 'live']
# THE TOP 15 WORDS FOR TOPIC #27
# ['like', 'think', 'bone', 'young', 'brain', 'finger', 'babe', 'come', 'head', 'simple', 'crack', 'leave', 'forgive', 'build', 'hand']
# THE TOP 15 WORDS FOR TOPIC #28
# ['fuck', 'kiss', 'line', 'hate', 'gettin', 'fine', 'ghetto', 'roll', 'strange', 'heavy', 'care', 'tell', 'like', 'drug', 'habit']
# THE TOP 15 WORDS FOR TOPIC #29
# ['hold', 'hand', 'tight', 'beautiful', 'stand', 'water', 'right', 'like', 'tell', 'lock', 'come', 'guilty', 'brother', 'strong', 'land']
# It took 10.378083229064941 seconds to generate LDA_topics.csv

# %%
topic_dist_LDA = lda.transform(tf_unigram)

# %%
lyrics['Topic_LDA'] = topic_dist_LDA.argmax(axis=1)
lyrics.sample(10) #show random rows
# Out:
#                 artist_name               track_name  release_date genre  \
# 1765                   abba   i saw it in the mirror          1973   pop
# 4691        destiny's child               hey ladies          1999   pop
# 3712   they might be giants             particle man          1990   pop
# 3330              big black                bad penny          1987   pop
# 27300           matt maeson             put it on me          2018  rock
# 26647          audrey assad                 restless          2010  rock
# 19185          judy garland             i got rhythm          1994  jazz
# 5712               bon iver               blindsided          2008   pop
# 19976   devin townsend band                  vampira          2006  jazz
# 20307            helen kane  i wanna be loved by you          2011  jazz
#
#                                                   lyrics       topic  \
# 1765   mirror face longer need place mirror look eye ...     sadness
# 4691   ladies wrong decide holdin strength leave ladi...     obscene
# 3712   particle particle things particle like importa...    violence
# 3330   ought know liar ought know curse nature bless ...     obscene
# 27300  hang high blame blame street pain cold inescap...    violence
# 26647  dwell songs sing rise heavens rise heart heart...  world/life
# 19185  days sign need money bird tree sing song shoul...       music
# 5712   bike downtown lock board nail crouch like crow...    violence
# 19976  night follow go nowhow night darkness strong c...    violence
# 20307  greedy kind want simple know mind rest eye gli...    romantic
#
#       Topic_NMF2  Topic_LDA
# 1765           0         21
# 4691          11         26
# 3712           7         27
# 3330           8         21
# 27300         15         18
# 26647          9         26
# 19185         22         19
# 5712          29         29
# 19976          6         22
# 20307         17         17

# %%
s = lyrics['Topic_LDA'].groupby(lyrics['genre']).value_counts()
s.groupby('genre').head(3) # show the top 3 topics per genre
# Out:
# genre    Topic_LDA
# blues    7             443
#          21            369
#          22            303
# country  7            1036
#          21            554
#          25            401
# hip hop  11            697
#          22             33
#          7              18
# jazz     11            502
#          19            333
#          21            319
# pop      7             927
#          11            812
#          21            721
# reggae   11            491
#          22            175
#          18            158
# rock     7             433
#          22            398
#          21            370
# Name: Topic_LDA, dtype: int64
